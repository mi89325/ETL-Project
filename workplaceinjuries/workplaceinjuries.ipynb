# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
variable= pd.read_csv(r"C:\Users\stods\git\workplaceinjuries\9-10.csv")


variable.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6ea35e9ee248> in <module>
# ----> 1 variable= pd.read_csv(r"C:\Users\stods\git\workplaceinjuries\9-10.csv")
#       2
#       3
#       4 variable.head()
#
# ...

# %%
variable2= pd.read_csv(r"C:\Users\stods\git\workplaceinjuries\15-16.csv")
variable2.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-47ccd82daa84> in <module>
# ----> 1 variable2= pd.read_csv(r"C:\Users\stods\git\workplaceinjuries\15-16.csv")
#       2 variable2.head()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
x_axis =("October", "November", "December", "January", "February", "March", "April", "May", "June", "July", "August", "September")
Death_per_month2 = (109, 98, 93, 87, 76, 85, 82, 94, 109, 117, 117, 100)
y_axis = np.arange(len(Death_per_month2))
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.bar(x_axis, Death_per_month2, color="b", align="center")
plt.grid()
plt.xlabel('Month') 
plt.ylabel('Deaths Per Month') 
plt.title('Deaths Per Month 2009-2010')
# Out:
# Text(0.5, 1.0, 'Deaths Per Month 2009-2010')

# %%
x_axis =("October", "November", "December", "January", "February", "March", "April", "May", "June", "July", "August", "September")
Death_per_month1 = (81, 88, 67, 72, 85, 94, 97, 92, 110, 89, 103, 97)
y_axis = np.arange(len(Death_per_month1))
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.bar(x_axis, Death_per_month1, color="r", align="center")
plt.grid()
plt.xlabel('Month') 
plt.ylabel('Deaths Per Month') 
plt.title('Deaths Per Month 2015-2016')
# Out:
# Text(0.5, 1.0, 'Deaths Per Month 2015-2016')

# %%
N = 12
Death_per_month2_means = (109, 98, 93, 87, 76, 85, 82, 94, 109, 117, 117, 100)
Death_per_month1_means = (81, 88, 67, 72, 85, 94, 97, 92, 110, 89, 103, 97)
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')
ind = np.arange(N) 
width = 0.35       
plt.bar(ind, Death_per_month2_means, width, color="b", label='09-10')
plt.bar(ind + width, Death_per_month1_means, width, color="r",
    label='15-16')

plt.xlabel('Month') 
plt.ylabel('Deaths Per Month') 
plt.title('Month Comparison 09-10 vs 15-16')
plt.grid()
plt.xticks(ind + width / 2, ("October", "November", "December", "January", "February", "March", "April", "May", "June", "July", "August", "September"))
plt.legend(loc='best')
plt.show()

# %%
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k') 

Incidents  = {"2009_2010": [615, 185, 119, 30, 18, 51, 46, 32, 20, 332, 11],

                       "2015_2016":[676, 286, 7, 35, 25, 0, 44, 18, 0, 143, 6]};

index = ["Falls", "Crushed", "Electrocuted", "Weapon used", "Suffocation or drowned", "Ran over", "Forklift", "Burn", "Heart related", "Insect stings", "Explosion"];


dataFrame.plot.barh(title="Incident Comparison 2009-2010 vs 2015-2016");
plt.grid()
plt.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-336b218fdb22> in <module>
#       8
#       9
# ---> 10 dataFrame.plot.barh(title="Incident Comparison 2009-2010 vs 2015-2016");
#      11 plt.grid()
#      12 plt.show(block=True);
#
# NameError: name 'dataFrame' is not defined

# %%
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')

fig, ax = plt.subplots()

Incidents = ("Falls", "Crushed", "Electrocuted", "Weapon used", "Suffocation or drowned", "Ran over", "Forklift", "Burn", "Heart related", "Insect stings", "Explosion")
y_pos = np.arange(len(Incidents))

Number_of_incidents_9 = np.array([615, 185, 119, 30, 18, 51, 46, 32, 20, 332, 11])
Number_of_incidents_15 = np.array([676, 286, 7, 35, 25, 0, 44, 18, 0, 143, 6])

ax.barh(y_pos, Number_of_incidents_9)
#ax.barh(y_pos, Number_of_incidents_15)
#ax.set_yticks(y_pos)
ax.set_yticklabels(Incidents)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of Incidents')
ax.set_title('Incdients 2009-2010')

plt.show()

# %%
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')

fig, ax = plt.subplots()
plt.grid()

Incidents = ("Falls", "Crushed", "Electrocuted", "Weapon used", "Suffocation or drowned", "Ran over", "Forklift", "Burn", "Heart related", "Insect stings", "Explosion")
y_pos = np.arange(len(Incidents))

#performance = 3 + 10 * np.random.rand(len(Incidents))
#error = np.random.rand(len(Incidents))

Number_of_incidents_9 = np.array([615, 185, 119, 30, 18, 51, 46, 32, 20, 332, 11])
Number_of_incidents_15 = np.array([676, 286, 7, 35, 25, 0, 44, 18, 0, 143, 6])

#ax.barh(y_pos, Number_of_incidents_9)
ax.barh(y_pos, Number_of_incidents_15)
#ax.set_yticks(y_pos)
ax.set_yticklabels(Incidents)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of Incidents')
ax.set_title('Incidents 2015-2016')

plt.show()

# %%
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k') 
Incidents  = {"2009_2010": [615, 185, 119, 30, 18, 51, 46, 32, 20, 332, 11],

                       "2015_2016":[676, 286, 7, 35, 25, 0, 44, 18, 0, 143, 6]};

index = ["Falls", "Crushed", "Electrocuted", "Weapon used", "Suffocation or drowned", "Ran over", "Forklift", "Burn", "Heart related", "Insect stings", "Explosion"];


dataFrame.plot.barh(title="Incident Comparison 2009-2010 vs 2015-2016");
plt.grid()
plt.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5dae876f1d68> in <module>
#       7
#       8
# ----> 9 dataFrame.plot.barh(title="Incident Comparison 2009-2010 vs 2015-2016");
#      10 plt.grid()
#      11 plt.show(block=True);
#
# NameError: name 'dataFrame' is not defined
